# %% [markdown]
# # Description
#
# ## --- Day 7: No Space Left On Device ---
#
# You can hear birds chirping and raindrops hitting leaves as the expedition proceeds. Occasionally, you can even hear much louder sounds in the distance; how big do the animals get out here, anyway?
#
# The device the Elves gave you has problems with more than just its communication system. You try to run a system update:
#
# ```sh
# $ system-update --please --pretty-please-with-sugar-on-top
# Error: No space left on device
# ```
#
# Perhaps you can delete some files to make space for the update?
#
# You browse around the filesystem to assess the situation and save the resulting terminal output (your puzzle input). For example:
#
# ```sh
# $ cd /
# $ ls
# dir a
# 14848514 b.txt
# 8504156 c.dat
# dir d
# $ cd a
# $ ls
# dir e
# 29116 f
# 2557 g
# 62596 h.lst
# $ cd e
# $ ls
# 584 i
# $ cd ..
# $ cd ..
# $ cd d
# $ ls
# 4060174 j
# 8033020 d.log
# 5626152 d.ext
# 7214296 k
# ```
#
# The filesystem consists of a tree of files (plain data) and directories (which can contain other directories or files). The outermost directory is called /. You can navigate around the filesystem, moving into or out of directories and listing the contents of the directory you're currently in.
#
# Within the terminal output, lines that begin with $ are commands you executed, very much like some modern computers:
#
# - cd means change directory. This changes which directory is the current directory, but the specific result depends on the argument:
#   - cd x moves in one level: it looks in the current directory for the directory named x and makes it the current directory.
#   - cd .. moves out one level: it finds the directory that contains the current directory, then makes that directory the current directory.
#   - cd / switches the current directory to the outermost directory, /.
# - ls means list. It prints out all of the files and directories immediately contained by the current directory:
#   - 123 abc means that the current directory contains a file named abc with size 123.
#   - dir xyz means that the current directory contains a directory named xyz.
#
# Given the commands and output in the example above, you can determine that the filesystem looks visually like this:
#
# - `/ (dir)`
#   - `a (dir)`
#     - `e (dir)`
#       - `i (file, size=584)`
#     - `f (file, size=29116)`
#     - `g (file, size=2557)`
#     - `h.lst (file, size=62596)`
#   - `b.txt (file, size=14848514)`
#   - `c.dat (file, size=8504156)`
#   - `d (dir)`
#     - `j (file, size=4060174)`
#     - `d.log (file, size=8033020)`
#     - `d.ext (file, size=5626152)`
#     - `k (file, size=7214296)`
#
# Here, there are four directories: / (the outermost directory), a and d (which are in /), and e (which is in a). These directories also contain files of various sizes.
#
# Since the disk is full, your first step should probably be to find directories that are good candidates for deletion. To do this, you need to determine the total size of each directory. The total size of a directory is the sum of the sizes of the files it contains, directly or indirectly. (Directories themselves do not count as having any intrinsic size.)
#
# The total sizes of the directories above can be found as follows:
#
# - The total size of directory e is 584 because it contains a single file i of size 584 and no other directories.
# - The directory a has total size 94853 because it contains files f (size 29116), g (size 2557), and h.lst (size 62596), plus file i indirectly (a contains e which contains i).
# - Directory d has total size 24933642.
#     As the outermost directory, / contains every file. Its total size is 48381165, the sum of the size of every file.
#
# To begin, find all of the directories with a total size of at most 100000, then calculate the sum of their total sizes. In the example above, these directories are a and e; the sum of their total sizes is 95437 (94853 + 584). (As in this example, this process can count files more than once!)
#
# Find all of the directories with a total size of at most 100000. What is the sum of the total sizes of those directories?
#
# Your puzzle answer was 1444896.
#
# ## --- Part Two ---
#
# Now, you're ready to choose a directory to delete.
#
# The total disk space available to the filesystem is 70000000. To run the update, you need unused space of at least 30000000. You need to find a directory you can delete that will free up enough space to run the update.
#
# In the example above, the total size of the outermost directory (and thus the total amount of used space) is 48381165; this means that the size of the unused space must currently be 21618835, which isn't quite the 30000000 required by the update. Therefore, the update still requires a directory with total size of at least 8381165 to be deleted before it can run.
#
# To achieve this, you have the following options:
#
# - Delete directory e, which would increase unused space by 584.
# - Delete directory a, which would increase unused space by 94853.
# - Delete directory d, which would increase unused space by 24933642.
# - Delete directory /, which would increase unused space by 48381165.
#
# Directories e and a are both too small; deleting them would not free up enough space. However, directories d and / are both big enough! Between these, choose the smallest: d, increasing unused space by 24933642.
#
# Find the smallest directory that, if deleted, would free up enough space on the filesystem to run the update. What is the total size of that directory?
#
# Your puzzle answer was 404395.

# %%
import json

lines = open('input/input.txt').read().splitlines()

root = {'name': '/', 'size': 0, 'subdirs': [], "path": ""}


def findParent(currentPath, root):
  current = root
  for d in currentPath:
    for subdir in current['subdirs']:
      if subdir['name'] == d:
        current = subdir
        break
  return current

def addToAll(path, size):
  current = root
  current['size'] += size

  for d in path.split('/')[1:]:
    for subdir in current['subdirs']:
      if subdir['name'] == d:
        current = subdir
        current['size'] += size
        break

for line in lines:
  path = line[4:].strip()
  if line.startswith('$ cd'):
    if path == '/':
      current = root
    elif path == '..':
      currentPath = current['path'].split('/')
      current = findParent(currentPath[1:-1], root)  # find parent of current
    else:
      found = False
      for subdir in current['subdirs']:
        if subdir['name'] == path:
          current = subdir
          found = True
          break
      if not found:
        print('not found', path, current['path'])
        current['subdirs'].append({'name': path, 'size': 0, 'subdirs': [], "path": current['path'] + "/" + path})
        current = current['subdirs'][-1]
  elif line.startswith('dir'):
    current['subdirs'].append({'name': path, 'size': 0, 'subdirs': [
    ], "path": current['path'] + "/" + path})
  elif line[0].isnumeric():
    size, _ = line.split(' ', 1)
    addToAll(current['path'], int(size))
    
print(json.dumps(root, indent=2))
# Out:
# {
#   "name": "/",
#   "size": 40389918,
#   "subdirs": [
#     {
#       "name": "bnl",
#       "size": 4283758,
#       "subdirs": [
#         {
#           "name": "dhw",
#           "size": 237421,
#           "subdirs": [],
#           "path": "/bnl/dhw"
#         },
#         {
#           "name": "dmpsnhdh",
#           "size": 2089974,
#           "subdirs": [
#             {
#               "name": "chf",
#               "size": 573029,
#               "subdirs": [
#                 {
#                   "name": "zfgznbz",
#                   "size": 350983,
#                   "subdirs": [],
#                   "path": "/bnl/dmpsnhdh/chf/zfgznbz"
#                 }
#               ],
#               "path": "/bnl/dmpsnhdh/chf"
#             },
#             {
#               "name": "mjpbhjm",
#               "size": 1375812,
#               "subdirs": [
#                 {
#                   "name": "crf",
#                   "size": 497521,
#                   "subdirs": [],
#                   "path": "/bnl/dmpsnhdh/mjpbhjm/crf"
#                 },
#                 {
#                   "name": "hqnj",
#                   "size": 339702,
#                   "subdirs": [],
#                   "path": "/bnl/dmpsnhdh/mjpbhjm/hqnj"
#                 },
#                 {
#                   "name": "lmw",
#                   "size": 50307,
#                   "subdirs": [],
#                   "path": "/bnl/dmpsnhdh/mjpbhjm/lmw"
#                 }
#               ],
#               "path": "/bnl/dmpsnhdh/mjpbhjm"
#             },
#             {
#               "name": "zwhpwp",
#               "size": 141133,
#               "subdirs": [],
#               "path": "/bnl/dmpsnhdh/zwhpwp"
#             }
#           ],
#           "path": "/bnl/dmpsnhdh"
#         },
#         {
#           "name": "lmw",
#           "size": 779209,
#           "subdirs": [
#             {
#               "name": "dvv",
#               "size": 216597,
#               "subdirs": [],
#               "path": "/bnl/lmw/dvv"
#             }
#           ],
#           "path": "/bnl/lmw"
#         },
#         {
#           "name": "vgbqbrst",
#           "size": 1177154,
#           "subdirs": [
#             {
#               "name": "jbdtpnw",
#               "size": 27543,
#               "subdirs": [],
#               "path": "/bnl/vgbqbrst/jbdtpnw"
#             },
#             {
#               "name": "rflp",
#               "size": 221045,
#               "subdirs": [],
#               "path": "/bnl/vgbqbrst/rflp"
#             },
#             {
#               "name": "twpq",
#               "size": 92924,
#               "subdirs": [
#                 {
#                   "name": "rlbsdj",
#                   "size": 56078,
#                   "subdirs": [],
#                   "path": "/bnl/vgbqbrst/twpq/rlbsdj"
#                 }
#               ],
#               "path": "/bnl/vgbqbrst/twpq"
#             }
#           ],
#           "path": "/bnl/vgbqbrst"
#         }
#       ],
#       "path": "/bnl"
#     },
#     {
#       "name": "dmpsnhdh",
#       "size": 3192609,
#       "subdirs": [
#         {
#           "name": "fnpwwhtj",
#           "size": 514966,
#           "subdirs": [
#             {
#               "name": "cgp",
#               "size": 514966,
#               "subdirs": [],
#               "path": "/dmpsnhdh/fnpwwhtj/cgp"
#             }
#           ],
#           "path": "/dmpsnhdh/fnpwwhtj"
#         },
#         {
#           "name": "lmw",
#           "size": 2482179,
#           "subdirs": [
#             {
#               "name": "bfbv",
#               "size": 92667,
#               "subdirs": [],
#               "path": "/dmpsnhdh/lmw/bfbv"
#             },
#             {
#               "name": "rrqjwpm",
#               "size": 117064,
#               "subdirs": [],
#               "path": "/dmpsnhdh/lmw/rrqjwpm"
#             },
#             {
#               "name": "sngm",
#               "size": 2215519,
#               "subdirs": [
#                 {
#                   "name": "lmw",
#                   "size": 177203,
#                   "subdirs": [
#                     {
#                       "name": "glwr",
#                       "size": 144719,
#                       "subdirs": [],
#                       "path": "/dmpsnhdh/lmw/sngm/lmw/glwr"
#                     }
#                   ],
#                   "path": "/dmpsnhdh/lmw/sngm/lmw"
#                 },
#                 {
#                   "name": "lqd",
#                   "size": 925297,
#                   "subdirs": [
#                     {
#                       "name": "jnjqmvg",
#                       "size": 104947,
#                       "subdirs": [],
#                       "path": "/dmpsnhdh/lmw/sngm/lqd/jnjqmvg"
#                     },
#                     {
#                       "name": "lmw",
#                       "size": 389245,
#                       "subdirs": [],
#                       "path": "/dmpsnhdh/lmw/sngm/lqd/lmw"
#                     }
#                   ],
#                   "path": "/dmpsnhdh/lmw/sngm/lqd"
#                 },
#                 {
#                   "name": "szn",
#                   "size": 197974,
#                   "subdirs": [],
#                   "path": "/dmpsnhdh/lmw/sngm/szn"
#                 }
#               ],
#               "path": "/dmpsnhdh/lmw/sngm"
#             }
#           ],
#           "path": "/dmpsnhdh/lmw"
#         }
#       ],
#       "path": "/dmpsnhdh"
#     },
#     {
#       "name": "fcnqg",
#       "size": 769565,
#       "subdirs": [],
#       "path": "/fcnqg"
#     },
#     {
#       "name": "jvwtm",
#       "size": 8509877,
#       "subdirs": [
#         {
#           "name": "dmpsnhdh",
#           "size": 1375783,
#           "subdirs": [
#             {
#               "name": "llhp",
#               "size": 180255,
#               "subdirs": [],
#               "path": "/jvwtm/dmpsnhdh/llhp"
#             },
#             {
#               "name": "mnsbh",
#               "size": 267627,
#               "subdirs": [],
#               "path": "/jvwtm/dmpsnhdh/mnsbh"
#             },
#             {
#               "name": "mpplsfjp",
#               "size": 476965,
#               "subdirs": [
#                 {
#                   "name": "bnl",
#                   "size": 243223,
#                   "subdirs": [],
#                   "path": "/jvwtm/dmpsnhdh/mpplsfjp/bnl"
#                 }
#               ],
#               "path": "/jvwtm/dmpsnhdh/mpplsfjp"
#             }
#           ],
#           "path": "/jvwtm/dmpsnhdh"
#         },
#         {
#           "name": "tlr",
#           "size": 1219467,
#           "subdirs": [
#             {
#               "name": "vcsngm",
#               "size": 36434,
#               "subdirs": [],
#               "path": "/jvwtm/tlr/vcsngm"
#             },
#             {
#               "name": "wndmt",
#               "size": 1183033,
#               "subdirs": [
#                 {
#                   "name": "fvmtfcqd",
#                   "size": 237025,
#                   "subdirs": [],
#                   "path": "/jvwtm/tlr/wndmt/fvmtfcqd"
#                 },
#                 {
#                   "name": "nvdb",
#                   "size": 338644,
#                   "subdirs": [],
#                   "path": "/jvwtm/tlr/wndmt/nvdb"
#                 },
#                 {
#                   "name": "nwqqgl",
#                   "size": 337354,
#                   "subdirs": [
#                     {
#                       "name": "cljbrh",
#                       "size": 133820,
#                       "subdirs": [],
#                       "path": "/jvwtm/tlr/wndmt/nwqqgl/cljbrh"
#                     }
#                   ],
#                   "path": "/jvwtm/tlr/wndmt/nwqqgl"
#                 },
#                 {
#                   "name": "sbspgnpm",
#                   "size": 270010,
#                   "subdirs": [],
#                   "path": "/jvwtm/tlr/wndmt/sbspgnpm"
#                 }
#               ],
#               "path": "/jvwtm/tlr/wndmt"
#             }
#           ],
#           "path": "/jvwtm/tlr"
#         },
#         {
#           "name": "twpq",
#           "size": 1226742,
#           "subdirs": [
#             {
#               "name": "dmpsnhdh",
#               "size": 575779,
#               "subdirs": [],
#               "path": "/jvwtm/twpq/dmpsnhdh"
#             },
#             {
#               "name": "hbchdjjp",
#               "size": 301016,
#               "subdirs": [],
#               "path": "/jvwtm/twpq/hbchdjjp"
#             }
#           ],
#           "path": "/jvwtm/twpq"
#         },
#         {
#           "name": "wbgcsw",
#           "size": 3609909,
#           "subdirs": [
#             {
#               "name": "bnl",
#               "size": 1615223,
#               "subdirs": [
#                 {
#                   "name": "fbbr",
#                   "size": 84414,
#                   "subdirs": [],
#                   "path": "/jvwtm/wbgcsw/bnl/fbbr"
#                 },
#                 {
#                   "name": "mzfrdl",
#                   "size": 625824,
#                   "subdirs": [
#                     {
#                       "name": "cjdptqgh",
#                       "size": 159918,
#                       "subdirs": [],
#                       "path": "/jvwtm/wbgcsw/bnl/mzfrdl/cjdptqgh"
#                     },
#                     {
#                       "name": "hwdnrqns",
#                       "size": 254432,
#                       "subdirs": [
#                         {
#                           "name": "dmpsnhdh",
#                           "size": 254432,
#                           "subdirs": [],
#                           "path": "/jvwtm/wbgcsw/bnl/mzfrdl/hwdnrqns/dmpsnhdh"
#                         }
#                       ],
#                       "path": "/jvwtm/wbgcsw/bnl/mzfrdl/hwdnrqns"
#                     },
#                     {
#                       "name": "prq",
#                       "size": 75827,
#                       "subdirs": [],
#                       "path": "/jvwtm/wbgcsw/bnl/mzfrdl/prq"
#                     }
#                   ],
#                   "path": "/jvwtm/wbgcsw/bnl/mzfrdl"
#                 },
#                 {
#                   "name": "tqgrdz",
#                   "size": 251475,
#                   "subdirs": [],
#                   "path": "/jvwtm/wbgcsw/bnl/tqgrdz"
#                 },
#                 {
#                   "name": "ztrnq",
#                   "size": 387873,
#                   "subdirs": [],
#                   "path": "/jvwtm/wbgcsw/bnl/ztrnq"
#                 }
#               ],
#               "path": "/jvwtm/wbgcsw/bnl"
#             },
#             {
#               "name": "bqq",
#               "size": 202201,
#               "subdirs": [],
#               "path": "/jvwtm/wbgcsw/bqq"
#             },
#             {
#               "name": "ctnlpgt",
#               "size": 269484,
#               "subdirs": [],
#               "path": "/jvwtm/wbgcsw/ctnlpgt"
#             },
#             {
#               "name": "hbqm",
#               "size": 117203,
#               "subdirs": [],
#               "path": "/jvwtm/wbgcsw/hbqm"
#             },
#             {
#               "name": "zqmjwsgz",
#               "size": 146194,
#               "subdirs": [],
#               "path": "/jvwtm/wbgcsw/zqmjwsgz"
#             },
#             {
#               "name": "zwwphs",
#               "size": 209587,
#               "subdirs": [],
#               "path": "/jvwtm/wbgcsw/zwwphs"
#             }
#           ],
#           "path": "/jvwtm/wbgcsw"
#         },
#         {
#           "name": "zjmldjdh",
#           "size": 1030017,
#           "subdirs": [
#             {
#               "name": "cdq",
#               "size": 289173,
#               "subdirs": [],
#               "path": "/jvwtm/zjmldjdh/cdq"
#             },
#             {
#               "name": "mdclfbs",
#               "size": 404395,
#               "subdirs": [
#                 {
#                   "name": "hpdgt",
#                   "size": 107421,
#                   "subdirs": [],
#                   "path": "/jvwtm/zjmldjdh/mdclfbs/hpdgt"
#                 }
#               ],
#               "path": "/jvwtm/zjmldjdh/mdclfbs"
#             },
#             {
#               "name": "tfc",
#               "size": 204406,
#               "subdirs": [],
#               "path": "/jvwtm/zjmldjdh/tfc"
#             }
#           ],
#           "path": "/jvwtm/zjmldjdh"
#         }
#       ],
#       "path": "/jvwtm"
#     },
#     {
#       "name": "ldztz",
#       "size": 978231,
#       "subdirs": [
#         {
#           "name": "dmpsnhdh",
#           "size": 524132,
#           "subdirs": [],
#           "path": "/ldztz/dmpsnhdh"
#         },
#         {
#           "name": "lbqgz",
#           "size": 171931,
#           "subdirs": [],
#           "path": "/ldztz/lbqgz"
#         },
#         {
#           "name": "znrnj",
#           "size": 153738,
#           "subdirs": [],
#           "path": "/ldztz/znrnj"
#         }
#       ],
#       "path": "/ldztz"
#     },
#     {
#       "name": "lmmw",
#       "size": 1507116,
#       "subdirs": [
#         {
#           "name": "bqqnsfdj",
#           "size": 1008403,
#           "subdirs": [
#             {
#               "name": "bnl",
#               "size": 808144,
#               "subdirs": [
#                 {
#                   "name": "lmw",
#                   "size": 156532,
#                   "subdirs": [
#                     {
#                       "name": "sfj",
#                       "size": 156532,
#                       "subdirs": [],
#                       "path": "/lmmw/bqqnsfdj/bnl/lmw/sfj"
#                     }
#                   ],
#                   "path": "/lmmw/bqqnsfdj/bnl/lmw"
#                 },
#                 {
#                   "name": "nqw",
#                   "size": 59928,
#                   "subdirs": [],
#                   "path": "/lmmw/bqqnsfdj/bnl/nqw"
#                 }
#               ],
#               "path": "/lmmw/bqqnsfdj/bnl"
#             },
#             {
#               "name": "tlnbvhdl",
#               "size": 183301,
#               "subdirs": [],
#               "path": "/lmmw/bqqnsfdj/tlnbvhdl"
#             }
#           ],
#           "path": "/lmmw/bqqnsfdj"
#         },
#         {
#           "name": "rlpcqtzg",
#           "size": 258638,
#           "subdirs": [],
#           "path": "/lmmw/rlpcqtzg"
#         }
#       ],
#       "path": "/lmmw"
#     },
#     {
#       "name": "wthvqw",
#       "size": 224501,
#       "subdirs": [],
#       "path": "/wthvqw"
#     },
#     {
#       "name": "zpdnprb",
#       "size": 20646114,
#       "subdirs": [
#         {
#           "name": "bnl",
#           "size": 520152,
#           "subdirs": [
#             {
#               "name": "pnzmp",
#               "size": 236287,
#               "subdirs": [
#                 {
#                   "name": "btbtlrs",
#                   "size": 107651,
#                   "subdirs": [],
#                   "path": "/zpdnprb/bnl/pnzmp/btbtlrs"
#                 }
#               ],
#               "path": "/zpdnprb/bnl/pnzmp"
#             }
#           ],
#           "path": "/zpdnprb/bnl"
#         },
#         {
#           "name": "ffg",
#           "size": 57918,
#           "subdirs": [],
#           "path": "/zpdnprb/ffg"
#         },
#         {
#           "name": "jljlwpsv",
#           "size": 346425,
#           "subdirs": [],
#           "path": "/zpdnprb/jljlwpsv"
#         },
#         {
#           "name": "rrqjwpm",
#           "size": 9290252,
#           "subdirs": [
#             {
#               "name": "bftw",
#               "size": 1561114,
#               "subdirs": [
#                 {
#                   "name": "brl",
#                   "size": 297937,
#                   "subdirs": [],
#                   "path": "/zpdnprb/rrqjwpm/bftw/brl"
#                 },
#                 {
#                   "name": "lmw",
#                   "size": 166695,
#                   "subdirs": [],
#                   "path": "/zpdnprb/rrqjwpm/bftw/lmw"
#                 },
#                 {
#                   "name": "rrqjwpm",
#                   "size": 198762,
#                   "subdirs": [],
#                   "path": "/zpdnprb/rrqjwpm/bftw/rrqjwpm"
#                 },
#                 {
#                   "name": "twpq",
#                   "size": 141835,
#                   "subdirs": [],
#                   "path": "/zpdnprb/rrqjwpm/bftw/twpq"
#                 },
#                 {
#                   "name": "vnfhb",
#                   "size": 128626,
#                   "subdirs": [],
#                   "path": "/zpdnprb/rrqjwpm/bftw/vnfhb"
#                 },
#                 {
#                   "name": "wcldzp",
#                   "size": 285142,
#                   "subdirs": [
#                     {
#                       "name": "ncq",
#                       "size": 133331,
#                       "subdirs": [
#                         {
#                           "name": "wrtw",
#                           "size": 133331,
#                           "subdirs": [],
#                           "path": "/zpdnprb/rrqjwpm/bftw/wcldzp/ncq/wrtw"
#                         }
#                       ],
#                       "path": "/zpdnprb/rrqjwpm/bftw/wcldzp/ncq"
#                     },
#                     {
#                       "name": "twpq",
#                       "size": 151811,
#                       "subdirs": [],
#                       "path": "/zpdnprb/rrqjwpm/bftw/wcldzp/twpq"
#                     }
#                   ],
#                   "path": "/zpdnprb/rrqjwpm/bftw/wcldzp"
#                 }
#               ],
#               "path": "/zpdnprb/rrqjwpm/bftw"
#             },
#             {
#               "name": "ccsfws",
#               "size": 100548,
#               "subdirs": [],
#               "path": "/zpdnprb/rrqjwpm/ccsfws"
#             },
#             {
#               "name": "wwfgbzqh",
#               "size": 7050334,
#               "subdirs": [
#                 {
#                   "name": "lmw",
#                   "size": 2864435,
#                   "subdirs": [
#                     {
#                       "name": "bgl",
#                       "size": 2423491,
#                       "subdirs": [
#                         {
#                           "name": "lmw",
#                           "size": 233655,
#                           "subdirs": [],
#                           "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/lmw"
#                         },
#                         {
#                           "name": "rrqjwpm",
#                           "size": 2189836,
#                           "subdirs": [
#                             {
#                               "name": "hsvnmlp",
#                               "size": 264517,
#                               "subdirs": [],
#                               "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/rrqjwpm/hsvnmlp"
#                             },
#                             {
#                               "name": "nsch",
#                               "size": 714999,
#                               "subdirs": [
#                                 {
#                                   "name": "lmw",
#                                   "size": 69572,
#                                   "subdirs": [],
#                                   "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/rrqjwpm/nsch/lmw"
#                                 },
#                                 {
#                                   "name": "sgjsg",
#                                   "size": 38856,
#                                   "subdirs": [],
#                                   "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/rrqjwpm/nsch/sgjsg"
#                                 }
#                               ],
#                               "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/rrqjwpm/nsch"
#                             },
#                             {
#                               "name": "qlgg",
#                               "size": 276013,
#                               "subdirs": [],
#                               "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/rrqjwpm/qlgg"
#                             },
#                             {
#                               "name": "twpq",
#                               "size": 370831,
#                               "subdirs": [],
#                               "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/rrqjwpm/twpq"
#                             }
#                           ],
#                           "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/rrqjwpm"
#                         }
#                       ],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl"
#                     },
#                     {
#                       "name": "jqthwzj",
#                       "size": 128200,
#                       "subdirs": [],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw/jqthwzj"
#                     }
#                   ],
#                   "path": "/zpdnprb/rrqjwpm/wwfgbzqh/lmw"
#                 },
#                 {
#                   "name": "mfms",
#                   "size": 641673,
#                   "subdirs": [
#                     {
#                       "name": "rmwtvjt",
#                       "size": 74490,
#                       "subdirs": [],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/mfms/rmwtvjt"
#                     }
#                   ],
#                   "path": "/zpdnprb/rrqjwpm/wwfgbzqh/mfms"
#                 },
#                 {
#                   "name": "pjbjgbcl",
#                   "size": 1510920,
#                   "subdirs": [
#                     {
#                       "name": "cswvftzs",
#                       "size": 545967,
#                       "subdirs": [
#                         {
#                           "name": "dchqnbns",
#                           "size": 94111,
#                           "subdirs": [],
#                           "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/cswvftzs/dchqnbns"
#                         },
#                         {
#                           "name": "smf",
#                           "size": 451856,
#                           "subdirs": [
#                             {
#                               "name": "dlnsgvl",
#                               "size": 156473,
#                               "subdirs": [
#                                 {
#                                   "name": "dsz",
#                                   "size": 156473,
#                                   "subdirs": [],
#                                   "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/cswvftzs/smf/dlnsgvl/dsz"
#                                 }
#                               ],
#                               "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/cswvftzs/smf/dlnsgvl"
#                             },
#                             {
#                               "name": "zglt",
#                               "size": 295383,
#                               "subdirs": [],
#                               "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/cswvftzs/smf/zglt"
#                             }
#                           ],
#                           "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/cswvftzs/smf"
#                         }
#                       ],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/cswvftzs"
#                     },
#                     {
#                       "name": "jtvtg",
#                       "size": 260673,
#                       "subdirs": [],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/jtvtg"
#                     },
#                     {
#                       "name": "lmw",
#                       "size": 8097,
#                       "subdirs": [],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/lmw"
#                     },
#                     {
#                       "name": "tnctbjr",
#                       "size": 368045,
#                       "subdirs": [
#                         {
#                           "name": "gzrcqr",
#                           "size": 117215,
#                           "subdirs": [
#                             {
#                               "name": "fnzgsnv",
#                               "size": 117215,
#                               "subdirs": [],
#                               "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/tnctbjr/gzrcqr/fnzgsnv"
#                             }
#                           ],
#                           "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/tnctbjr/gzrcqr"
#                         }
#                       ],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/tnctbjr"
#                     },
#                     {
#                       "name": "tqsrfhdr",
#                       "size": 96381,
#                       "subdirs": [],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/tqsrfhdr"
#                     }
#                   ],
#                   "path": "/zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl"
#                 },
#                 {
#                   "name": "wzqbwr",
#                   "size": 1602652,
#                   "subdirs": [
#                     {
#                       "name": "dpbcgfdr",
#                       "size": 1107794,
#                       "subdirs": [
#                         {
#                           "name": "jvn",
#                           "size": 350765,
#                           "subdirs": [],
#                           "path": "/zpdnprb/rrqjwpm/wwfgbzqh/wzqbwr/dpbcgfdr/jvn"
#                         },
#                         {
#                           "name": "wzpbbbhm",
#                           "size": 143534,
#                           "subdirs": [],
#                           "path": "/zpdnprb/rrqjwpm/wwfgbzqh/wzqbwr/dpbcgfdr/wzpbbbhm"
#                         }
#                       ],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/wzqbwr/dpbcgfdr"
#                     },
#                     {
#                       "name": "swp",
#                       "size": 131295,
#                       "subdirs": [],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/wzqbwr/swp"
#                     },
#                     {
#                       "name": "zhj",
#                       "size": 200002,
#                       "subdirs": [],
#                       "path": "/zpdnprb/rrqjwpm/wwfgbzqh/wzqbwr/zhj"
#                     }
#                   ],
#                   "path": "/zpdnprb/rrqjwpm/wwfgbzqh/wzqbwr"
#                 }
#               ],
#               "path": "/zpdnprb/rrqjwpm/wwfgbzqh"
#             }
#           ],
#           "path": "/zpdnprb/rrqjwpm"
#         },
#         {
#           "name": "twpq",
#           "size": 5296583,
#           "subdirs": [
#             {
#               "name": "bppvlwqs",
#               "size": 474285,
#               "subdirs": [],
#               "path": "/zpdnprb/twpq/bppvlwqs"
#             },
#             {
#               "name": "bvh",
#               "size": 66958,
#               "subdirs": [
#                 {
#                   "name": "lmw",
#                   "size": 66958,
#                   "subdirs": [],
#                   "path": "/zpdnprb/twpq/bvh/lmw"
#                 }
#               ],
#               "path": "/zpdnprb/twpq/bvh"
#             },
#             {
#               "name": "rmcdr",
#               "size": 3617232,
#               "subdirs": [
#                 {
#                   "name": "dmpsnhdh",
#                   "size": 515068,
#                   "subdirs": [
#                     {
#                       "name": "rrqjwpm",
#                       "size": 326594,
#                       "subdirs": [
#                         {
#                           "name": "bnl",
#                           "size": 245600,
#                           "subdirs": [],
#                           "path": "/zpdnprb/twpq/rmcdr/dmpsnhdh/rrqjwpm/bnl"
#                         },
#                         {
#                           "name": "lmw",
#                           "size": 73396,
#                           "subdirs": [],
#                           "path": "/zpdnprb/twpq/rmcdr/dmpsnhdh/rrqjwpm/lmw"
#                         }
#                       ],
#                       "path": "/zpdnprb/twpq/rmcdr/dmpsnhdh/rrqjwpm"
#                     }
#                   ],
#                   "path": "/zpdnprb/twpq/rmcdr/dmpsnhdh"
#                 },
#                 {
#                   "name": "pmrdhrth",
#                   "size": 351685,
#                   "subdirs": [],
#                   "path": "/zpdnprb/twpq/rmcdr/pmrdhrth"
#                 },
#                 {
#                   "name": "zbmcrvbh",
#                   "size": 2227079,
#                   "subdirs": [
#                     {
#                       "name": "lmw",
#                       "size": 1438328,
#                       "subdirs": [
#                         {
#                           "name": "bbbll",
#                           "size": 635197,
#                           "subdirs": [],
#                           "path": "/zpdnprb/twpq/rmcdr/zbmcrvbh/lmw/bbbll"
#                         },
#                         {
#                           "name": "mlz",
#                           "size": 115167,
#                           "subdirs": [],
#                           "path": "/zpdnprb/twpq/rmcdr/zbmcrvbh/lmw/mlz"
#                         }
#                       ],
#                       "path": "/zpdnprb/twpq/rmcdr/zbmcrvbh/lmw"
#                     },
#                     {
#                       "name": "qfrvdm",
#                       "size": 284564,
#                       "subdirs": [],
#                       "path": "/zpdnprb/twpq/rmcdr/zbmcrvbh/qfrvdm"
#                     },
#                     {
#                       "name": "rcg",
#                       "size": 116435,
#                       "subdirs": [
#                         {
#                           "name": "sqzjz",
#                           "size": 116435,
#                           "subdirs": [],
#                           "path": "/zpdnprb/twpq/rmcdr/zbmcrvbh/rcg/sqzjz"
#                         }
#                       ],
#                       "path": "/zpdnprb/twpq/rmcdr/zbmcrvbh/rcg"
#                     }
#                   ],
#                   "path": "/zpdnprb/twpq/rmcdr/zbmcrvbh"
#                 }
#               ],
#               "path": "/zpdnprb/twpq/rmcdr"
#             },
#             {
#               "name": "tdn",
#               "size": 764730,
#               "subdirs": [
#                 {
#                   "name": "pstpclp",
#                   "size": 354281,
#                   "subdirs": [],
#                   "path": "/zpdnprb/twpq/tdn/pstpclp"
#                 }
#               ],
#               "path": "/zpdnprb/twpq/tdn"
#             },
#             {
#               "name": "wwtwnvh",
#               "size": 371148,
#               "subdirs": [],
#               "path": "/zpdnprb/twpq/wwtwnvh"
#             }
#           ],
#           "path": "/zpdnprb/twpq"
#         },
#         {
#           "name": "vlgsrtm",
#           "size": 4922703,
#           "subdirs": [
#             {
#               "name": "dmpsnhdh",
#               "size": 459053,
#               "subdirs": [
#                 {
#                   "name": "lltnrdtv",
#                   "size": 270424,
#                   "subdirs": [],
#                   "path": "/zpdnprb/vlgsrtm/dmpsnhdh/lltnrdtv"
#                 },
#                 {
#                   "name": "scthsg",
#                   "size": 188629,
#                   "subdirs": [
#                     {
#                       "name": "rrqjwpm",
#                       "size": 188629,
#                       "subdirs": [],
#                       "path": "/zpdnprb/vlgsrtm/dmpsnhdh/scthsg/rrqjwpm"
#                     }
#                   ],
#                   "path": "/zpdnprb/vlgsrtm/dmpsnhdh/scthsg"
#                 }
#               ],
#               "path": "/zpdnprb/vlgsrtm/dmpsnhdh"
#             },
#             {
#               "name": "fjsglr",
#               "size": 253602,
#               "subdirs": [
#                 {
#                   "name": "pnsjwfzc",
#                   "size": 113848,
#                   "subdirs": [],
#                   "path": "/zpdnprb/vlgsrtm/fjsglr/pnsjwfzc"
#                 }
#               ],
#               "path": "/zpdnprb/vlgsrtm/fjsglr"
#             },
#             {
#               "name": "lmw",
#               "size": 1188146,
#               "subdirs": [
#                 {
#                   "name": "ffhcf",
#                   "size": 40478,
#                   "subdirs": [],
#                   "path": "/zpdnprb/vlgsrtm/lmw/ffhcf"
#                 },
#                 {
#                   "name": "jpgqspqw",
#                   "size": 22181,
#                   "subdirs": [],
#                   "path": "/zpdnprb/vlgsrtm/lmw/jpgqspqw"
#                 },
#                 {
#                   "name": "pfsjwmbc",
#                   "size": 225892,
#                   "subdirs": [
#                     {
#                       "name": "bcvchw",
#                       "size": 225892,
#                       "subdirs": [],
#                       "path": "/zpdnprb/vlgsrtm/lmw/pfsjwmbc/bcvchw"
#                     }
#                   ],
#                   "path": "/zpdnprb/vlgsrtm/lmw/pfsjwmbc"
#                 }
#               ],
#               "path": "/zpdnprb/vlgsrtm/lmw"
#             },
#             {
#               "name": "lqgrft",
#               "size": 1469401,
#               "subdirs": [
#                 {
#                   "name": "rrqjwpm",
#                   "size": 57839,
#                   "subdirs": [],
#                   "path": "/zpdnprb/vlgsrtm/lqgrft/rrqjwpm"
#                 },
#                 {
#                   "name": "twpq",
#                   "size": 1411562,
#                   "subdirs": [
#                     {
#                       "name": "lmw",
#                       "size": 521518,
#                       "subdirs": [
#                         {
#                           "name": "lmw",
#                           "size": 139640,
#                           "subdirs": [],
#                           "path": "/zpdnprb/vlgsrtm/lqgrft/twpq/lmw/lmw"
#                         },
#                         {
#                           "name": "lngbszqm",
#                           "size": 381878,
#                           "subdirs": [],
#                           "path": "/zpdnprb/vlgsrtm/lqgrft/twpq/lmw/lngbszqm"
#                         }
#                       ],
#                       "path": "/zpdnprb/vlgsrtm/lqgrft/twpq/lmw"
#                     },
#                     {
#                       "name": "mhgqt",
#                       "size": 208165,
#                       "subdirs": [],
#                       "path": "/zpdnprb/vlgsrtm/lqgrft/twpq/mhgqt"
#                     }
#                   ],
#                   "path": "/zpdnprb/vlgsrtm/lqgrft/twpq"
#                 }
#               ],
#               "path": "/zpdnprb/vlgsrtm/lqgrft"
#             },
#             {
#               "name": "rmdp",
#               "size": 337538,
#               "subdirs": [
#                 {
#                   "name": "bqn",
#                   "size": 75628,
#                   "subdirs": [],
#                   "path": "/zpdnprb/vlgsrtm/rmdp/bqn"
#                 }
#               ],
#               "path": "/zpdnprb/vlgsrtm/rmdp"
#             },
#             {
#               "name": "vgjzqjpq",
#               "size": 273695,
#               "subdirs": [
#                 {
#                   "name": "bnl",
#                   "size": 25911,
#                   "subdirs": [],
#                   "path": "/zpdnprb/vlgsrtm/vgjzqjpq/bnl"
#                 },
#                 {
#                   "name": "wpfw",
#                   "size": 247784,
#                   "subdirs": [],
#                   "path": "/zpdnprb/vlgsrtm/vgjzqjpq/wpfw"
#                 }
#               ],
#               "path": "/zpdnprb/vlgsrtm/vgjzqjpq"
#             },
#             {
#               "name": "ztnqnfnq",
#               "size": 356707,
#               "subdirs": [
#                 {
#                   "name": "dtpzsrfc",
#                   "size": 142652,
#                   "subdirs": [],
#                   "path": "/zpdnprb/vlgsrtm/ztnqnfnq/dtpzsrfc"
#                 }
#               ],
#               "path": "/zpdnprb/vlgsrtm/ztnqnfnq"
#             }
#           ],
#           "path": "/zpdnprb/vlgsrtm"
#         }
#       ],
#       "path": "/zpdnprb"
#     }
#   ],
#   "path": ""
# }

# %% [markdown]
# # Part 1

# %%
# find all of the directories with a total size of at most 100000
def checkDir(root, total):
    s = root['size']
    condition = 0 < s <= 10**5
    if condition:
        print(f"| {root['path']:69} | {s:10} |")
        total.append(s)

    for subdir in root['subdirs']:
        checkDir(subdir, total)
    return total

d = '-'*86
print(d)
print(d, f"\n| {'Sum':69} | {sum(checkDir(root, [])):10} |", f"\n{d}")
# Out:
# --------------------------------------------------------------------------------------
# | /bnl/dmpsnhdh/mjpbhjm/lmw                                             |      50307 |
# | /bnl/vgbqbrst/jbdtpnw                                                 |      27543 |
# | /bnl/vgbqbrst/twpq                                                    |      92924 |
# | /bnl/vgbqbrst/twpq/rlbsdj                                             |      56078 |
# | /dmpsnhdh/lmw/bfbv                                                    |      92667 |
# | /jvwtm/tlr/vcsngm                                                     |      36434 |
# | /jvwtm/wbgcsw/bnl/fbbr                                                |      84414 |
# | /jvwtm/wbgcsw/bnl/mzfrdl/prq                                          |      75827 |
# | /lmmw/bqqnsfdj/bnl/nqw                                                |      59928 |
# | /zpdnprb/ffg                                                          |      57918 |
# | /zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/rrqjwpm/nsch/lmw                    |      69572 |
# | /zpdnprb/rrqjwpm/wwfgbzqh/lmw/bgl/rrqjwpm/nsch/sgjsg                  |      38856 |
# | /zpdnprb/rrqjwpm/wwfgbzqh/mfms/rmwtvjt                                |      74490 |
# | /zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/cswvftzs/dchqnbns                  |      94111 |
# | /zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/lmw                                |       8097 |
# | /zpdnprb/rrqjwpm/wwfgbzqh/pjbjgbcl/tqsrfhdr                           |      96381 |
# | /zpdnprb/twpq/bvh                                                     |      66958 |
# | /zpdnprb/twpq/bvh/lmw                                                 |      66958 |
# | /zpdnprb/twpq/rmcdr/dmpsnhdh/rrqjwpm/lmw                              |      73396 |
# | /zpdnprb/vlgsrtm/lmw/ffhcf                                            |      40478 |
# | /zpdnprb/vlgsrtm/lmw/jpgqspqw                                         |      22181 |
# | /zpdnprb/vlgsrtm/lqgrft/rrqjwpm                                       |      57839 |
# | /zpdnprb/vlgsrtm/rmdp/bqn                                             |      75628 |
# | /zpdnprb/vlgsrtm/vgjzqjpq/bnl                                         |      25911 |
# --------------------------------------------------------------------------------------
# | Sum                                                                   |    1444896 |
# --------------------------------------------------------------------------------------

# %% [markdown]
# # Part 2

# %%
def flatten(root, flat):
  flat.append(root['size'])
  for subdir in root['subdirs']:
    flatten(subdir, flat)
  return flat
    
flat = flatten(root, [])

t = 4*10**7

sorted(filter(lambda x: x > root["size"] - t, flat))[0]
# Out:
# 404395
